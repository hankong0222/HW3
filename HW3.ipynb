# %% [markdown]
# For the left skewness, the mean is less than median; for the right skewness, the mean is greater than median.That's because the right tail for right skewness is bigger, more items accumulate in the bigger values. The other bigger value than the normal distribution makes the mean value become bigger, however, in the same time, median not change. Median is less sensitive than mean.

# %%
import plotly.express as px
from scipy import stats
import pandas as pd
import numpy as np

# Generate the right-skewed (positive) sample
sample1 = stats.gamma(a=2, scale=2).rvs(size=1000)
fig1 = px.histogram(pd.DataFrame({'data': sample1}), x="data", title="Right-Skewed (Positive) Distribution")
fig1.show(renderer="png")  # For GitHub and MarkUs submissions

# Mean and median of sample1 (right-skewed)
mean1 = sample1.mean()
median1 = np.quantile(sample1, 0.5)  # 0.5 quantile is the median

print(f"Sample 1 (Right-Skewed) Mean: {mean1}")
print(f"Sample 1 (Right-Skewed) Median: {median1}")

# Generate the left-skewed (negative) sample by negating the gamma distribution
sample2 = -stats.gamma(a=2, scale=2).rvs(size=1000)
fig2 = px.histogram(pd.DataFrame({'data': sample2}), x="data", title="Left-Skewed (Negative) Distribution")
fig2.show(renderer="png")  # For GitHub and MarkUs submissions

# Mean and median of sample2 (left-skewed)
mean2 = sample2.mean()
median2 = np.quantile(sample2, 0.5)  # 0.5 quantile is the median

print(f"Sample 2 (Left-Skewed) Mean: {mean2}")
print(f"Sample 2 (Left-Skewed) Median: {median2}")
# Out:
# Sample 1 (Right-Skewed) Mean: 4.0456853093932486
# Sample 1 (Right-Skewed) Median: 3.2738389767789133
# Sample 2 (Left-Skewed) Mean: -3.9530819036758813
# Sample 2 (Left-Skewed) Median: -3.313895136221553

# %% [markdown]
# from the visualization of the data, we can see that for right skewed distribution(sample 1), the mean is greater than median, and for left skewed distribution, the mean is less than the median.That's there is more values distribute on the left side(left tail) for left skewed distribution than small, makes the mean becomes smaller. But the median is less sensitive, it only depends on the center of the dataset.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2024/2024-08-13/worlds_fairs.csv")
df # df.columns
# Out:
#     start_month  start_year  end_month  end_year  \
# 0             4        1851         10      1851
# 1             5        1855         11      1855
# 2             5        1862         11      1862
# 3             4        1867         11      1867
# 4             5        1873         10      1873
# ..          ...         ...        ...       ...
# 65            5        2010         10      2010
# 66            5        2012          8      2012
# 67            5        2015         10      2015
# 68            6        2017          9      2017
# 69           10        2021          3      2022
#
#                                    name_of_exposition  \
# 0                                The Great Exhibition
# 1        Exposition Universelle / Paris International
# 2                            International Exhibition
# 3        Exposition Universelle / Paris International
# 4   Weltausstellung 1873 Wien / Austrian Internati...
# ..                                                ...
# 65                                          Expo 2010
# 66                                          Expo 2012
# 67                                          Expo 2015
# 68                                          Expo 2017
# 69                                          Expo 2020
#
#                        country      city          category  \
# 0               United Kingdom    London        World Expo
# 1                       France     Paris        World Expo
# 2               United Kingdom    London        World Expo
# 3                       France     Paris        World Expo
# 4              Austria-Hungary    Vienna        World Expo
# ..                         ...       ...               ...
# 65  People's Republic of China  Shanghai        World Expo
# 66                 South Korea     Yeosu  Specialised Expo
# 67                       Italy     Milan        World Expo
# 68                  Kazakhstan    Astana  Specialised Expo
# 69        United Arab Emirates     Dubai        World Expo
#
#                                     theme  \
# 0                 Industry of all Nations
# 1          Agriculture, Industry and Arts
# 2                       Industry and Arts
# 3          Agriculture, Industry and Arts
# 4                   Culture and Education
# ..                                    ...
# 65               Better City, Better Life
# 66             The Living Ocean and Coast
# 67    Feeding the planet, Energy for life
# 68                          Future Energy
# 69  Connecting Minds, Creating the Future
#
#                                              notables  visitors    cost  \
# 0                                  The Crystal Palace     6.000   165.0
# 1    Palais d'Industrie, Bordeaux Wine classification     5.000     2.0
# 2                                                 NaN     6.000     2.0
# 3                                       Champ de Mars    15.000    45.0
# 4                                             Rotunde     7.250    95.0
# ..                                                ...       ...     ...
# 65  Expo Axis, Oriental Crown (Currently China Art...    73.080  4200.0
# 66                             The Big-OThe Sky Tower     8.200  1769.0
# 67                                   The Tree of Life    21.500     NaN
# 68                                The Nur Alem Sphere     4.100     NaN
# 69                                      Al Wasl Plaza    24.103     NaN
#
#      area  attending_countries
# 0    10.0                 25.0
# 1    15.0                 25.0
# 2    15.0                 39.0
# 3    69.0                 42.0
# 4   233.0                 35.0
# ..    ...                  ...
# 65  523.0                192.0
# 66   25.0                103.0
# 67  110.0                145.0
# 68   25.0                115.0
# 69  438.0                192.0
#
# [70 rows x 14 columns]

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2024/2024-08-13/worlds_fairs.csv")

# Preview the data
print(df.head())

# Check column names
print(df.columns)
# Out:
#    start_month  start_year  end_month  end_year  \
# 0            4        1851         10      1851
# 1            5        1855         11      1855
# 2            5        1862         11      1862
# 3            4        1867         11      1867
# 4            5        1873         10      1873
#
#                                   name_of_exposition          country    city  \
# 0                               The Great Exhibition   United Kingdom  London
# 1       Exposition Universelle / Paris International           France   Paris
# 2                           International Exhibition   United Kingdom  London
# 3       Exposition Universelle / Paris International           France   Paris
# 4  Weltausstellung 1873 Wien / Austrian Internati...  Austria-Hungary  Vienna
#
#      category                           theme  \
# 0  World Expo         Industry of all Nations
# 1  World Expo  Agriculture, Industry and Arts
# 2  World Expo               Industry and Arts
# 3  World Expo  Agriculture, Industry and Arts
# 4  World Expo           Culture and Education
#
#                                            notables  visitors   cost   area  \
# 0                                The Crystal Palace      6.00  165.0   10.0
# 1  Palais d'Industrie, Bordeaux Wine classification      5.00    2.0   15.0
# 2                                               NaN      6.00    2.0   15.0
# 3                                     Champ de Mars     15.00   45.0   69.0
# 4                                           Rotunde      7.25   95.0  233.0
#
#    attending_countries
# 0                 25.0
# 1                 25.0
# 2                 39.0
# 3                 42.0
# 4                 35.0
# Index(['start_month', 'start_year', 'end_month', 'end_year',
#        'name_of_exposition', 'country', 'city', 'category', 'theme',
#        'notables', 'visitors', 'cost', 'area', 'attending_countries'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of world fairs by start year
plt.figure(figsize=(10, 6))
sns.histplot(df['start_year'], bins=20, kde=False, color='steelblue')

plt.title("Number of World Fairs Over Time", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Count of World Fairs", fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Scatter plot: Visitors over time
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='start_year', y='visitors', color='steelblue', s=100)

plt.title("Visitors at World Fairs Over Time", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Visitors (in millions)", fontsize=12)
plt.grid(True)
plt.show()

# %%
# Summary statistics
summary = df.describe()
print(summary)
# Out:
#        start_month   start_year  end_month     end_year   visitors  \
# count    70.000000    70.000000  70.000000    70.000000  56.000000
# mean      5.414286  1947.185714   9.157143  1947.285714  16.640232
# std       1.876575    44.263144   2.375208    44.262767  16.586385
# min       2.000000  1851.000000   1.000000  1851.000000   0.800000
# 25%       4.000000  1911.500000   9.000000  1911.500000   5.637500
# 50%       5.000000  1953.500000  10.000000  1953.500000  10.000000
# 75%       6.000000  1983.500000  11.000000  1983.500000  21.635000
# max      12.000000  2021.000000  12.000000  2022.000000  73.080000
#
#               cost        area  attending_countries
# count    36.000000   65.000000            65.000000
# mean    559.944444  105.816615            49.215385
# std     998.426532  116.986551            45.041471
# min       2.000000    0.080000             8.000000
# 25%      26.750000   30.000000            23.000000
# 50%     125.500000   70.000000            33.000000
# 75%     448.250000  120.000000            55.000000
# max    4200.000000  523.000000           192.000000

# %% [markdown]
# this is a analysis for numerical variables, it is discrete. Both the number of fairs over time and visitors distribute skewed to the left. That means that the number of visitors increase at the same time number of fairs increase over years. The mean for visitors is greater than the median. The mean for attending_countries is also greater than median. That's means the attending countries increase over time.The number of fairs max around the year 1950, however, the number of visitors max over year 2000, that's mean more fairs not implies more visitors.

# %%
import pandas as pd
import plotly.express as px

url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
df = pd.read_csv(url)

df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           size_max=55, range_x=[25,75], range_y=[0,40000])

fig.show()
# Out:
# <div>                            <div id="82c7cd7e-f40f-4ed0-9929-8191daee9af9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82c7cd7e-f40f-4ed0-9929-8191daee9af9")) {                    Plotly.newPlot(                        "82c7cd7e-f40f-4ed0-9929-8191daee9af9",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=Asia\u003cbr\u003eyear=1952\u003cbr\u003eGDP per Capita (Income)=%{x}\u003cbr\u003eLife Expectancy (Lifespan)=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thailand","Vietnam","West Bank and Gaza","Yemen, Rep."],"ids":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thailand","Vietnam","West Bank and Gaza","Yemen, Rep."],"legendgroup":"Asia","marker":{"color":"#636efa","size":[8425333.0,120447.0,46886859.0,4693836.0,556263528.0,2125900.0,372000000.0,82052000.0,17272000.0,5441766.0,1620914.0,86459025.0,607914.0,8865488.0,20947571.0,160000.0,1439529.0,6748378.0,800663.0,20092996.0,9182536.0,507833.0,41346560.0,22438691.0,4005677.0,1127000.0,7982342.0,3661549.0,8550362.0,21289402.0,26246839.0,1030585.0,4963829.0],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[779.4453145,9867.084765,684.2441716,368.4692856,400.4486107,3054.421209,546.5657493,749.6816546,3035.326002,4129.766056,4086.522128,3216.956347,1546.907807,1088.277758,1030.592226,108382.3529,4834.804067,1831.132894,786.5668575,331.0,545.8657229,1828.230307,684.5971438,1272.880995,6459.554823,2315.138227,1083.53203,1643.485354,1206.947913,757.7974177,605.0664917,1515.592329,781.7175761],"xaxis":"x","y":[28.801,50.939,37.484,39.417,44.0,60.96,37.373,37.468,44.869,45.32,65.39,63.03,43.158,50.056,47.453,55.565,55.928,48.463,42.244,36.319,36.157,37.578,43.436,47.752,39.875,60.396,57.593,45.883,58.5,50.848,40.412,43.16,32.548],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=Europe\u003cbr\u003eyear=1952\u003cbr\u003eGDP per Capita (Income)=%{x}\u003cbr\u003eLife Expectancy (Lifespan)=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Austria","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Denmark","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Turkey","United Kingdom"],"ids":["Albania","Austria","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Denmark","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Turkey","United Kingdom"],"legendgroup":"Europe","marker":{"color":"#EF553B","size":[1282697.0,6927772.0,8730405.0,2791000.0,7274900.0,3882229.0,9125183.0,4334000.0,4090500.0,42459667.0,69145952.0,7733250.0,9504000.0,147962.0,2952156.0,47666000.0,413834.0,10381988 ...

# %%
bn = pd.read_csv('https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv')
bn['name'] = bn['name']+" "+bn['sex'] # make identical boy and girl names distinct
bn['rank'] = bn.groupby('year')['percent'].rank(ascending=False)
bn = bn.sort_values(['name','year'])
# the next three lines create the increaes or decrease in name prevalence from the last year 
bn['percent change'] = bn['percent'].diff()
new_name = [True]+list(bn.name[:-1].values!=bn.name[1:].values)
bn.loc[new_name,'percentage change'] = bn.loc[new_name,'percent'] 
bn = bn.sort_values('year')
bn = bn[bn.percent>0.001] # restrict to "common" names
fig = px.scatter(bn, x="percentage change", y="rank", animation_frame="year", animation_group="name",
                 size="percent", color="sex", hover_name="name",size_max=50, range_x=[-0.005,0.005]) # range_y removed
fig.update_yaxes(autorange='reversed') # this lets us put rank 1 on the top
fig.show(renderer="png") # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS

# %% [markdown]
# yes

# %% [markdown]
# In this chat, we discussed the relationship between the mean and median in skewed distributions, and how your provided code demonstrates this concept.
#
# Mean vs. Median:
#
# The mean is the arithmetic average and is affected by extreme values (outliers).
# The median is the middle value of a dataset and is less influenced by outliers.
# Right-Skewed (Positive Skewness):
#
# The distribution has a long tail on the right.
# The mean is greater than the median because outliers on the right pull the mean higher.
# Left-Skewed (Negative Skewness):
#
# The distribution has a long tail on the left.
# The mean is less than the median because outliers on the left pull the mean lower.
# Your Code:
#
# You created right- and left-skewed distributions using the Gamma distribution and visualized them with histograms.
# By calculating and comparing the mean and median, the code demonstrates the expected relationships: mean > median in the right-skewed case and mean < median in the left-skewed case.
# This conversation clarified how skewness affects the relationship between the mean and median, and how your code illustrates this concept.
#
# https://chatgpt.com/share/66f61990-3660-8006-bfb7-143bc2489d5b
